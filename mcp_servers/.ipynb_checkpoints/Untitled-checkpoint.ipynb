# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

# %%
{
    "command": "fastmcp",
    "args": [
        "run",
        "mcp_servers/expense_tracker.py:mcp_ExpenseTracker",
        "--no-banner",
        "--reload"
    ],
    "env": {
        "APPDATA": "C:\\Users\\vivek\\AppData\\Roaming",
        "HOMEDRIVE": "C:",
        "HOMEPATH": "\\Users\\vivek",
        "LOCALAPPDATA": "C:\\Users\\vivek\\AppData\\Local",
        "PATH": "C:\\Users\\vivek\\AppData\\Local\\npm-cache\\_npx\\5a9d879542beca3a\\node_modules\\.bin;D:\\MCPs\\node_modules\\.bin;D:\\node_modules\\.bin;C:\\Program Files\\nodejs\\node_modules\\npm\\node_modules\\@npmcli\\run-script\\lib\\node-gyp-bin;D:\\MCPs\\.venv\\Scripts;D:\\MCPs\\.venv/Scripts;c:\\Users\\vivek\\AppData\\Roaming\\Code\\User\\globalStorage\\github.copilot-chat\\debugCommand;c:\\Users\\vivek\\AppData\\Roaming\\Code\\User\\globalStorage\\github.copilot-chat\\copilotCli;C:\\Users\\vivek\\AppData\\Local\\Programs\\Microsoft VS Code;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Users\\vivek\\AppData\\Roaming\\Python\\Python313\\Scripts;C:\\Program Files\\NVIDIA Corporation\\NVIDIA App\\NvDLISR;C:\\Program Files\\Git\\cmd;C:\\Program Files\\nodejs\\;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Users\\Vivek\\AppData\\Local\\Programs\\Python\\Python311\\;C:\\Users\\vivek\\AppData\\Local\\Programs\\Python\\Python311\\Scripts\\;C:\\Users\\vivek\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Program Files\\JetBrains\\PyCharm Community Edition 2023.2.5\\bin;;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\;C:\\Users\\vivek\\AppData\\Roaming\\npm;c:\\Users\\vivek\\.vscode\\extensions\\ms-python.debugpy-2025.18.0-win32-x64\\bundled\\scripts\\noConfigScripts",
        "PROCESSOR_ARCHITECTURE": "AMD64",
        "SYSTEMDRIVE": "C:",
        "SYSTEMROOT": "C:\\WINDOWS",
        "TEMP": "C:\\Users\\vivek\\AppData\\Local\\Temp",
        "USERNAME": "vivek",
        "USERPROFILE": "C:\\Users\\vivek",
        "PROGRAMFILES": "C:\\Program Files"
    }
}

# %%
{
    "mcpServers": {
        "default-server": {
            "command": "fastmcp",
            "args": [
                "run",
                "mcp_servers/expense_tracker.py:mcp_ExpenseTracker",
                "--no-banner",
                "--reload"
            ],
            "env": {
                "APPDATA": "C:\\Users\\vivek\\AppData\\Roaming",
                "HOMEDRIVE": "C:",
                "HOMEPATH": "\\Users\\vivek",
                "LOCALAPPDATA": "C:\\Users\\vivek\\AppData\\Local",
                "PATH": "C:\\Users\\vivek\\AppData\\Local\\npm-cache\\_npx\\5a9d879542beca3a\\node_modules\\.bin;D:\\MCPs\\node_modules\\.bin;D:\\node_modules\\.bin;C:\\Program Files\\nodejs\\node_modules\\npm\\node_modules\\@npmcli\\run-script\\lib\\node-gyp-bin;D:\\MCPs\\.venv\\Scripts;D:\\MCPs\\.venv/Scripts;c:\\Users\\vivek\\AppData\\Roaming\\Code\\User\\globalStorage\\github.copilot-chat\\debugCommand;c:\\Users\\vivek\\AppData\\Roaming\\Code\\User\\globalStorage\\github.copilot-chat\\copilotCli;C:\\Users\\vivek\\AppData\\Local\\Programs\\Microsoft VS Code;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Users\\vivek\\AppData\\Roaming\\Python\\Python313\\Scripts;C:\\Program Files\\NVIDIA Corporation\\NVIDIA App\\NvDLISR;C:\\Program Files\\Git\\cmd;C:\\Program Files\\nodejs\\;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Users\\Vivek\\AppData\\Local\\Programs\\Python\\Python311\\;C:\\Users\\vivek\\AppData\\Local\\Programs\\Python\\Python311\\Scripts\\;C:\\Users\\vivek\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Program Files\\JetBrains\\PyCharm Community Edition 2023.2.5\\bin;;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\;C:\\Users\\vivek\\AppData\\Roaming\\npm;c:\\Users\\vivek\\.vscode\\extensions\\ms-python.debugpy-2025.18.0-win32-x64\\bundled\\scripts\\noConfigScripts",
                "PROCESSOR_ARCHITECTURE": "AMD64",
                "SYSTEMDRIVE": "C:",
                "SYSTEMROOT": "C:\\WINDOWS",
                "TEMP": "C:\\Users\\vivek\\AppData\\Local\\Temp",
                "USERNAME": "vivek",
                "USERPROFILE": "C:\\Users\\vivek",
                "PROGRAMFILES": "C:\\Program Files"
            }
        }
    }
}

# %%
servers = {
  "mcpServers": {
    "Expense_Tracker": {
      "transport": "stdio",
      "command": "uv",
      "args": [
        "run",
        "fastmcp",
        "run",
        "mcp_servers/expense_tracker.py"
      ],
      "env": {
        "PYTHONPATH": "."
      }
    }
  }
}

# %%
from asyncio import run

# %%
async def main():
    client = MultiServerMCPClient(servers)
    tools = await client.get_tools()
    return tools

# %%
tools = await main()
# Out:
# -----------------------------------------
# ValueErrorTraceback (most recent call last)
# Cell In[21], line 1
# ----> 1 tools = await main()
#
# Cell In[20], line 3, in main()
#       1 async def main():
#       2     client = MultiServerMCPClient(servers)
# ----> 3     tools = await client.get_tools()
#       4     return tools
#
# File D:\MCPs\.venv\Lib\site-packages\langchain_mcp_adapters\client.py:197, in MultiServerMCPClient.get_tools(self, server_name)
#     186     load_mcp_tool_task = asyncio.create_task(
#     187         load_mcp_tools(
#     188             None,
#    (...)    194         )
#     195     )
#     196     load_mcp_tool_tasks.append(load_mcp_tool_task)
# --> 197 tools_list = await asyncio.gather(*load_mcp_tool_tasks)
#     198 for tools in tools_list:
#     199     all_tools.extend(tools)
#
# ...
