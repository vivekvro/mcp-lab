# %%
l = ["a","b","c"]

print("\n\n".join(l))
# Out:
# a
#
# b
#
# c

# %%
import json

# %%
with open("configs\mcp_server_config.json","r") as file :
    x = json.load(file)

# %%
x
# Out:
# {'expense-tracker': {'transport': 'streamable_http',
#   'url': 'https://expense-tracker-8001.fastmcp.app/mcp'}}

# %%
x
# Out:
# {'transport': 'streamable_http',
#  'url': 'https://expense-tracker-8001.fastmcp.app/mcp'}

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
x
# Out:
# {'expense-tracker': {'transport': 'streamable_http',
#   'url': 'https://expense-tracker-8001.fastmcp.app/mcp'}}

# %%
x
# Out:
# {'expense-tracker': {'transport': 'streamable_http',
#   'url': 'https://expense-tracker-8001.fastmcp.app/mcp'},
#  'avg': {'avf': 1, 'qwe': 12}}

# %%
def get_db_path(user_id:str):
    n =user_id.replace(" ","")
    return f"{n}.db"
# Out:
#   Cell In[2], line 2
#     return f"{user_id.replace(" ","")}.db"
#                                           ^
# SyntaxError: f-string: unmatched '('
